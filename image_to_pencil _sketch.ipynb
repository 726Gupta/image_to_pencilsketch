# %% [markdown]
# # DATA SCIENCE INTERNSHIP AT LETSGROWMORE VIP

# %% [markdown]
# ## TASK-4: IMAGE TO PENCIL SKETCH

# %%
import cv2

# %%
# !pip install opencv.python
# Out:
# Requirement already satisfied: opencv.python in c:\users\shrey_0kio574\anaconda3\lib\site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\shrey_0kio574\anaconda3\lib\site-packages (from opencv.python) (1.24.3)

# %%
import cv2

# %%
image=cv2.imread("Parr.jpg")

# %%
cv2.imshow("person",image)

# %%
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib','inline')
img_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
grey_image=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
grey_image
# Out:
# array([[  4,   4,   4, ..., 254, 254, 254],
#        [  4,   4,   4, ..., 254, 254, 254],
#        [  4,   4,   4, ..., 254, 254, 254],
#        ...,
#        [238, 238, 238, ..., 238, 238, 238],
#        [238, 238, 238, ..., 238, 238, 238],
#        [238, 238, 238, ..., 238, 238, 238]], dtype=uint8)

# %%
plt.imshow(grey_image)

# %%
invert_image=255-grey_image
plt.imshow(invert_image)

# %%
blurred=cv2.GaussianBlur(invert_image,(21,21),0)
plt.imshow(blurred)

# %%
# Assuming 'blurred' is defined and has a value assigned to it before this point
invert_blurred = 255 - blurred
pencil_sketch = cv2.divide(grey_image, invert_blurred, scale=256.0)
plt.imshow(pencil_sketch)
#cv2.imshow("Sketch", pencil_sketch)

# %%
cv2.imshow("photo",pencil_sketch)

# %%
cv2.imshow("Original",image)
cv2.imshow("pencil sketch",pencil_sketch)

# %%
cv2.imshow("Original",image)
cv2.imshow("pencil sketch",pencil_sketch)
cv2.waitKey(0)
